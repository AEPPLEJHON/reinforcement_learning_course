# %%
import numpy as np

# %% [markdown]
# ### Problem 1
# #### (a.) Which action is better for bob when he starts out with $x_0=20$ kroner

# %% [markdown]
# We simply compute the expected return of each outcome.
# $$y_0 = 20$$
# $$y_1 = \frac{1}{4}\cdot 0 +\frac{3}{4}\cdot 32 = 3\cdot 8=24$$
# $u=1$ is the best policy.

# %% [markdown]
# #### (b.) Determine the policy $μ_0(x_0)$ which maximize Bobs earnings

# %% [markdown]
# $$
# g_0 = -x_0,\,\,
# g_1 = -x_0\frac{3}{4}-12\frac{3}{4}
# $$
# We select $u_1$ when
# $$
# g_1 < g_0
# $$
# $$
# -x_0 <-x_0\frac{3}{4}-12\frac{3}{4}\\
# x_0\frac{4}{3} <x_0+12\\
# x_0\frac{1}{3} <12\\
# x_0<36
# $$

# %%
x_0 = np.arange(1,40)
x_1 = (x_0 + 12)*3/4

print(x_1 > x_0)
print(x_0[-4])
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True False
#  False False False]
# 36
